# %%
import pandas as pd
import numpy as np
from utils import get_all_elements_in_dir

# %%
# data_dir = "platformer"
data = pd.read_csv("asp.csv")
# asp = pd.read_csv("asp.csv")
# asp["GroundTime"].mean()  
        
# sample_time_as_sec = asp["SampleTime"].astype(float) / 1e09
# cumlative_cost = asp["GroundTime"] / 1e09 +  sample_time_as_sec.cumsum()
# iter_num_samples =  pd.Series(range(len(sample_time_as_sec)))
# line = cumlative_cost / iter_num_samples


# for el in get_all_elements_in_dir(data_dir):
#     data = pd.read_csv(f"{data_dir}/{el}", dtype="str")
#     compile_time_as_sec =data["CompileTime"].astype(float) / 1e09
#     sample_time_as_sec =data["SampleTime"].astype(float) / 1e09
#     cumlative_cost = compile_time_as_sec + sample_time_as_sec.cumsum()
#     iter_num_samples =  pd.Series(range(len(sample_time_as_sec)))
#     plot_data = cumlative_cost / iter_num_samples
#     print(iter_num_samples)
#     t = plot_data[100:].plot(xlabel="Number of Samples", ylabel="Time to generate per number of samples")
#     line[100:].plot()
#     t.get_figure().savefig("temp-1.png")
# data = pd.read_csv("asp.csv")
data.columns
# Out:
# Index(['ASP', 'Tilsets', 'SolveTime', 'GroundTime', 'Hash', 'Dim'], dtype='object')

# %%
# t = data[data["Dimension"] == "2"]["CompileTime"].astype(float) + data[data["Dimension"] == "2"]["ComputeProbs"].astype(float)  
# t = data[data["Dimension"] == "2"]["SampleTime"].astype(float) 
# t = data["ComputeProbs"].astype(float) + data["CompileTime"].astype(float)
t = data["SolveTime"].astype(float)
mean = t.mean()
std =  t.std()
print(f"{mean} $\pm$ ({std})")

# len(data["Hash"].unique())
# data["Hash"]
# Out:
# 1016000.0 $\pm$ (125537.88177183714)
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_514258/4035758240.py:7: SyntaxWarning: invalid escape sequence '\p'
#   print(f"{mean} $\pm$ ({std})")

# %%
print(plot_data)
t = plot_data.plot(xlabel="Number of Samples", ylabel="Time to generate per number of samples", ylim=(0,0.2))
t.get_figure().savefig("linegonedown.png")
# Out:
# 0           inf
# 1      0.025522
# 2      0.019834
# 3      0.004386
# 4      0.003926
#          ...
# 888    0.001015
# 889    0.001015
# 890    0.001015
# 891    0.001015
# 892    0.001015
# Length: 893, dtype: float64
